# %% [markdown]
# <a href="https://colab.research.google.com/github/shuhaibshihab5000/datascienceprograms/blob/main/STONE_PAPER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#with computer stone paper scissor
import random
print("welcome to stone paper")
print("enter stone,paper,scissor :")
user=input("user input:")
computer="paper"
if computer==user:
  print(" both are same same")
elif(user=="scissor" and (user=="paper") and computer== "stone" or (user=="stone") and computer=="scissor"):
  print("you win nice play")
else:
  print("computer win bad luck")
# Out:
# welcome to stone paper
# enter stone,paper,scissor :
# user input:stone
# computer win bad luck

# %%
#without computer
print("welcome to the sps")
user_input=input("Choose STONE, PAPER, SCISSOR").lower() # Added .lower() for case-insensitive comparison
computer_choice="paper" # Corrected assignment operator
print("user_input=", user_input)
print ("computer_choice",computer_choice)
if user_input==computer_choice:
  print ("This is draw!")
elif  (user_input=="stone" and computer_choice=="scissor") or \
       (user_input=="paper"and computer_choice=="stone") or\
       (user_input=="scissor" and computer_choice=="paper"):
       print("You win!")
else:
      print ("Computer win!")
# Out:
# welcome to the sps

# %%
print("welcome to the world of rock n paper scissor")


import random
choices=["rock","paper","scissor"]

while True:

    try:
        user_choice=input("enter rock,paper,scissor")


        if user_choice not in choice:
           print("enter valid input like rock,paper,scissor")
           continue


        computer_choice=random.choice(choices)
        print("computer choice:" ,computer choice)

        if user_choice==random.choice:
           print("match draw")
        elif (
                (user_choice=="rock"and computer_choice == "scissor" ) or
                (user_choice == "paper" and computer_choice == "rock") or
                (user_choice == "scissors" and computer _choice == "paper")
              ):
                print ("You Win!")

        else:
            print("Computer Wins!")


            play_again = input("Do you want to play again? (yes/no): ")

            if play_again != "yes":
               print("Thanks for playing!")
               break
        except Exception as e:
           print("An error occurred: ", e)
