# %% [markdown]
# <a href="https://colab.research.google.com/github/shuhaibshihab5000/datascienceprograms/blob/main/guessing_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #guessing number creating program
e

print("guess my number")
secret_number=25
user_input=int(input("enter the guess number"))
if secret_number==user_input:
 print("congratulation your guessing number is valid")
else:
  print("sorry!,your guessing number is invalid")
# Out:
# guess my number
# enter the guess number78
# sorry!,your guessing number is invalid

# %%
#guessing number creating program


print("guess my number")
secret_number=25
user_input=int(input("enter the guess number"))
if secret_number==user_input:
 print("congratulation your guessing number is valid")
else:
  print("sorry!,your guessing number is invalid")
# Out:
# guess my number
# enter the guess number25
# congratulation your guessing number is valid

# %%
#guess secret number in 7 attempt


print("guess my number")
secret_number=25
for i in range(1,7):
  user_input=int(input("enter the guess number"))
  if secret_number==user_input:
   print("congratulation your guessing number is valid")
   break
  else:
   print("sorry!,your guessing number is invalid")
# Out:
# guess my number
# enter the guess number25
# congratulation your guessing number is valid

# %%
print("welcome to number guessing game")
print("guessing the number between 1=100")

secret_number=86
for i in range(0,8):
    user_input=int(input("enter your guess"))
    if user_input<1 or user_input>100:
        print("invalid number ! please enter the number between 1-100")
    elif user_input<secret_number:
        print("your number is lesser ")
    elif user_input>secret_number:
        print("your number is higher")

    else:
        print("your guess is correct")
        print(f"congratulation you have guessed the number {secret_number} in {i} attemt ")
        break
# Out:
# welcome to number guessing game
# guessing the number between 1=100
# enter your guess78
# your number is lesser
# enter your guess87
# your number is higher
# enter your guess86
# your guess is correct
# congratulation you have guessed the number 86 in 2 attemt

# %%
print("welcome to number guessing game")
print("guessing the number between 1=100")

secret_number=77
for i in range(0,8):
    user_input=int(input("enter your guess"))
    if user_input<1 or user_input>100:
        print("invalid number ! please enter the number between 1-100")
    elif user_input<secret_number:
        print("your number is lesser ")
    elif user_input>secret_number:
        print("your number is higher")

    else:
        print("your guess is correct")
        break
if secret_number==user_input:
        print(f"congratulation you have guessed the number {secret_number} in {i} attemt ")
else:
    print("sorry all your trails is exceed,try again")
# Out:
# welcome to number guessing game
# guessing the number between 1=100
# enter your guess67
# your number is lesser
# enter your guess78
# your number is higher
# enter your guess77
# your guess is correct
# congratulation you have guessed the number 77 in 2 attemt

# %%
#importing random

import random
print("welcome to number guessing game")
print("guessing the number between 1=100")

secret_number=random.randint(1,100)
for i in range(0,8):
    user_input=int(input("enter your guess"))
    if user_input<1 or user_input>100:
        print("invalid number ! please enter the number between 1-100")
    elif user_input<secret_number:
        print("your number is lesser ")
    elif user_input>secret_number:
        print("your number is higher")

    else:
        print("your guess is correct")
        break
if secret_number==user_input:
        print(f"congratulation you have guessed the number {secret_number} in {i} attemt ")
else:
    print("sorry all your trails is exceed,try again")
# Out:
# welcome to number guessing game
# guessing the number between 1=100
# your number is lesser
